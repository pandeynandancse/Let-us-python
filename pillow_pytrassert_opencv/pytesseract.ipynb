# %%
from PIL import Image

image = Image.open("/home/awadhi123/Downloads/Capture10.JPG")
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1338x557 at 0x7F521F7906A0>

# %%
import pytesseract
#dir(pytesseract)
#help(pytesseract.image_to_string)
#pytesseract.image_to_string??

# %%
text = pytesseract.image_to_string(image)
print(text)
# Out:
# a oe
#
#
#
#
#
# COS cud Ce Se Ua
#
# REASONING : QUESTION 1 OF 16 English ow Time Status
#
# A,B, Crent a pasture. A puts 10 oxen for 7 months, B puts 12 oxen for 5 months and C puts 15 oxen for 3 months for 00 * 29 ° 53
# grazing. If the rent of the pasture is Rs. 175, how much must C pay as his share of rent? . .
#
# 2 Mark(s)
#
#
#
# Total Time
#
# Reasoning
#
# me me goo000
# Rs. 55
# poooon
# a

# %%
img = image.convert('L')
a = img.save('nandanl.jpg')

# Now lets save that image
# And run OCR on the greyscale image
display(Image.open('nandanl.jpg'))
text = pytesseract.image_to_string(Image.open('nandanl.jpg')) 
print(text)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1338x557 at 0x7F521CFBD048>
# coe
#
#
#
# Cre CM Sco)
#
#
#
# ee acy
#
# REASONING : QUESTION 1 OF 16 English ow Time Status
#
# 9:53
#
# A,B, Crent a pasture. A puts 10 oxen for 7 months, B puts 12 oxen for 5 months and C puts 15 oxen for 3 months for 0 0 2)
# grazing. If the rent of the pasture is Rs. 175, how much must C pay as his share of rent? “*
#
#
#
# 2 Mark(s)
#
#
#
# Total Time
#
# Reasoning
#
# me me goo000
# Rs. 55
# Boooono
# a
